# %% [markdown]
# # Lec 3
# ### Reproducible Data Visualization

# %%
# start by loading our libraries and making some sample data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
# add a legend, using label = ...
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )

# We can modify legends

ax.legend(loc='lower right',
          frameon = True, #add frame around the legend
          fontsize = 12, #change font size
          ncol = 2, #specify number of columns
)

# loc='best' is for where it is least overlapped with data points

# Moving legends out of the plot area
"""
ax.legend(loc=‘upper left’,
bbox_to_anchor =(1, 1))
"""

fig.show()
# Out:
# C:\Users\94469\AppData\Local\Temp\ipykernel_42900\3738777981.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Annotations with text function

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

#Modifying text annotations
ax.text(10, 95, "This value is important!",
ha='center', ##alignment of text, ha is horizontal axis
color = 'red', ##modify font colour
size = 20) ##modify font size

fig.show()
# Out:
# C:\Users\94469\AppData\Local\Temp\ipykernel_42900\1479999873.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Positioning Text Annotations, using transforms

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

# The number is the percentage of where it is located, 0.5 is half way
ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData )
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes )
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure )

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
arrowprops=dict(facecolor='black'))
fig.show()
16
# Out:
# C:\Users\94469\AppData\Local\Temp\ipykernel_42900\2677510734.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# 16

# %% [markdown]
# Annotating with arrows

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
arrowprops=dict(facecolor='black'))
fig.show()
# Out:
# C:\Users\94469\AppData\Local\Temp\ipykernel_42900\3720401516.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Removing tick marks and labels
# Use locator to remove ticks and labels
# Use formatter to remove only labels

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

#Define max number of ticks
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

#Particular interval
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# Rotating axis labels
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])
